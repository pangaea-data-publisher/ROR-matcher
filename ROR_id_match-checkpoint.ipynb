# %%
import pandas as pd
import os

# %%
Fname="institution.csv"
Fdir="E:\PYTHON_work_learn\Python_work\Anu_Project\\from_Dropbox\\"
FnameFull=Fdir+Fname

# %%
FnameFull
# Out:
# 'E:\\PYTHON_work_learn\\Python_work\\Anu_Project\\from_Dropbox\\institution.csv'

# %%
df=pd.read_csv(FnameFull,header=None)

# %%
df.head(2)
# Out:
#    0              1                                             2   \
# 0   1  AWI@FRIGOROPA                    Polarstern core repository
# 1   4           GeoB  Department of Geosciences, Bremen University
#
#                   3                    4        5                  6   \
# 0  27572 Bremerhaven  hannes.grobe@awi.de  Germany  +49 471 4831 1149
# 1       28359 Bremen                  NaN  Germany   +49 421 218 3116
#
#                   7    8                     9   \
# 0  +49 471 4831 1220  NaN     Kühlhausstrasse 9
# 1   +49 421 218 3585  NaN  Klagenfurter Strasse
#
#                                                   10   11  12   13
# 0  http://www.awi-bremerhaven.de/GEO/CoreRepository/  NaN NaN  7.0
# 1    http://www.geo.uni-bremen.de/page.php?langid=EN  NaN NaN  7.0

# %%
colnamesstr="id_institution	abbreviation	name	city	contact	country	fax	phone	state	street	uri	uri_semantic	id_institution_type	id_user_created"

# %%
colnames=colnamesstr.split("\t")

# %%
df.columns=colnames
df.head()
# Out:
#    id_institution   abbreviation  \
# 0               1  AWI@FRIGOROPA
# 1               4           GeoB
# 2               5        GEOOSLO
# 3               6     IFM-GEOMAR
# 4               8           IMGP
#
#                                                 name               city  \
# 0                         Polarstern core repository  27572 Bremerhaven
# 1       Department of Geosciences, Bremen University       28359 Bremen
# 2      Department of Geosciences, University of Oslo      N-0316 Oslo 3
# 3  IFM-GEOMAR Leibniz-Institute of Marine Science...         24148 Kiel
# 4  Göttinger Zentrum für Geowissenschaften, Unive...    37077 Göttingen
#
#                      contact  country                fax  \
# 0        hannes.grobe@awi.de  Germany  +49 471 4831 1149
# 1                        NaN  Germany   +49 421 218 3116
# 2                        NaN   Norway     +47 22 85 4215
# 3  wbrueckmann@ifm-geomar.de  Germany   +49 431 600 2941
# 4                        NaN  Germany    +49 551 397 996
#
#                   phone state                  street  \
# 0     +49 471 4831 1220   NaN       Kühlhausstrasse 9
# 1      +49 421 218 3585   NaN    Klagenfurter Strasse
# 2        +47 22 85 6656   NaN  P.O. Box 1047 Blindern
# 3  +49 431 600 2500 Sec   NaN     Wischhofstrasse 1-3
# 4       +49 551 397 900   NaN   Goldschmidt-Strasse 3
#
#                                                  uri uri_semantic  \
# 0  http://www.awi-bremerhaven.de/GEO/CoreRepository/          NaN
# 1    http://www.geo.uni-bremen.de/page.php?langid=EN          NaN
# 2                     http://www.geo.uio.no/english/          NaN
# 3                               http://www.geomar.de          NaN
# 4                           http://www.imgp.gwdg.de/          NaN
#
#    id_institution_type  id_user_created
# 0                  NaN              7.0
# 1                  NaN              7.0
# 2                  NaN              7.0
# 3                  NaN              7.0
# 4                  NaN              7.0

# %% [markdown]
# ### Time to make some requests

# %%
import requests

# %% [markdown]
# ## Query functions

# %%
def getresponse(url,params):
    try:
        r=requests.get(url,params=params)
        if r.status_code!=200:
            raise requests.HTTPError
        return r
    except requests.exceptions.HTTPError:
        return("Http error!")
    except requests.exceptions.ConnectionError:
        return("Connection Error!")
    except requests.exceptions.Timeout:
        return("Timeout error!")
    except requests.exceptions.RequestException:
        return("Unknown  Requests error occured!")

# %%
def rparser(response):
    try:
        if type(response)!=requests.models.Response:
            raise TypeError
        jout=response.json()
        if jout["number_of_results"]!=0:
            return jout['items']
        else:
            print("empty response!")
            return None 
    except TypeError:
        return "wrong input type!"
    except KeyError:
        return "KeyError - query API error"

# %% [markdown]
# ## Query example (Bremen University)

# %% [markdown]
# Query parameters

# %%
name=df["name"][1]
name
# Out:
# 'Department of Geosciences, Bremen University'

# %%
country=df["country"][1]
country
# Out:
# 'Germany'

# %%
API_url="https://api.ror.org/organizations"
params={"query":[name],"filter":"country.country_name:"+country}

# %% [markdown]
# Query itself

# %%
r=getresponse(API_url,params)
r.text[0:400]
# Out:
# '{"number_of_results":537,"time_taken":12,"items":[{"id":"https://ror.org/04ers2y35","name":"University of Bremen","types":["Education"],"links":["http://www.uni-bremen.de/en.html"],"aliases":[],"acronyms":[],"wikipedia_url":"http://en.wikipedia.org/wiki/University_of_Bremen","labels":[{"label":"Universität Bremen","iso639":"de"}],"country":{"country_name":"Germany","country_code":"DE"},"external_i'

# %%
r.url
# Out:
# 'https://api.ror.org/organizations?query=Department+of+Geosciences%2C+Bremen+University&filter=country.country_name%3AGermany'

# %% [markdown]
# Fisrt 20 results. We will pick the first one and take its ROR_id. This is not going to work in some cases!

# %%
jdic=rparser(r)
[s["name"] for s in jdic]
# Out:
# ['University of Bremen',
#  'Jacobs University',
#  'Bremen University of Applied Sciences',
#  'University of the Arts Bremen',
#  'Universum Bremen',
#  'Staatsarchiv Bremen',
#  'Freie Universität Berlin',
#  'European Geosciences Union',
#  'Hochschule für Technik und Wirtschaft des Saarlandes',
#  'Hessische Hochschule für Polizei und Verwaltung',
#  'Hochschule Bremerhaven',
#  'Hochschule Mittweida',
#  'Klinikum Bremen-Mitte',
#  'Hochschule Osnabrück',
#  'Technische Hochschule Mittelhessen',
#  'Institute for Information Management Bremen',
#  'Hochschule Ulm',
#  'Fliedner Fachhochschule Düsseldorf',
#  'Hochschule für bildende Künste',
#  'Hochschule Magdeburg-Stendal']

# %%
print(jdic[0]["id"])
# Out:
# https://ror.org/04ers2y35

# %% [markdown]
# ## Query fill

# %% [markdown]
# lets create a list of ROR_id's received by taking the first element of a query result

# %%
qror_list=[None]*len(df) # creating an empty list of fixed size - of length of database entries
API_url="https://api.ror.org/organizations"

# %%
name=df["country"][9]
name
# Out:
# nan

# %%
def idreq(i):
    try:
        name=df["name"][i]
        country=df["country"][i]
        params={"query":[name],"filter":"country.country_name:"+country}
    except TypeError:
        return name,"TypeError occured while reading name or country"
    r=getresponse(API_url,params)
    jdic=rparser(r)
    if type(jdic)==list:
        return name,jdic[0]["id"]  # return the ROR id of the FIRST object of JSON
    else:
        return name,jdic

# %%
for s in range(999,len(df)+1):
    name,val=idreq(s)
    print("Iteration {s}, output === {p} // name==={n} \n #############".format(s=s,p=val,n=name))
    qror_list[s]=val
# Out:
# Iteration 999, output === https://ror.org/01xtthb56 // name===Section of Marine Botany, University of Oslo
#  #############
# Iteration 1000, output === https://ror.org/01xtthb56 // name===Section of Marine Zoology and Marine Chemistry, University of Oslo
#  #############
# Iteration 1001, output === https://ror.org/01xtthb56 // name===Department of Geophysics, University of Oslo
#  #############
# Iteration 1002, output === https://ror.org/01xtthb56 // name===Department of Mathematics, University of Oslo
#  #############
# Iteration 1003, output === https://ror.org/022bzg803 // name===Department of Pharmacology, Microbiology and Food Hygiene, Norwgian Centre of Ve
#  #############
# Iteration 1004, output === https://ror.org/00by76g53 // name===Department of Fish Health, Central Veterinary Laboratory
#  #############
# Iteration 1005, output === https://ror.org/0502t5s28 // name===RF-Rogaland Research
#  #############
# Iteration 1006, output === https://ror.org/05dz27378 // name===Norwegian Hydrographic Service, Statens Kartverk, Sjøkartverket
#  #############
# Iteration 1007, output === https://ror.org/03hrf8236 // name===Akvaplan-Niva
#  #############
# Iteration 1008, output === https://ror.org/01scevc62 // name===Norwegian College of Fisheries Science, University of Tromsø
#  #############
# Iteration 1009, output === https://ror.org/042cc7155 // name===SINTEF Petroleum Research
#  #############
# Iteration 1010, output === https://ror.org/042cc7155 // name===IKU Petroleum Research, SINTEF Group
#  #############
# Iteration 1011, output === https://ror.org/04aha0598 // name===Norwegian Institute for Nature Research
#  #############
# Iteration 1012, output === https://ror.org/004wre089 // name===Norwegian Marine Technology Research Institute
#  #############
# Iteration 1013, output === https://ror.org/05xg72x27 // name===Department of Biotechnology, Norwegian University of Science and Technology, NTN
#  #############
# Iteration 1014, output === https://ror.org/032ksge37 // name===Department of Geotechnical Engineering, Norwegian University of Science and Tech
#  #############
# Iteration 1015, output === https://ror.org/05xg72x27 // name===Department of Marine Hydrodynamics, Norwegian University of Science and Technolo
#  #############
# Iteration 1016, output === https://ror.org/05xg72x27 // name===Department of Structural Engineering, Norwegian University of Science and Techno
#  #############
# Iteration 1017, output === https://ror.org/05xg72x27 // name===Department of Telecommunications, Norwegian University of Science and Technology
#  #############
# Iteration 1018, output === https://ror.org/05xg72x27 // name===Department of Zoology, Norwegian University of Science and Technology, NTNU
#  #############
# Iteration 1019, output === https://ror.org/042y68y70 // name===Trondheim Biological Station, Norwegian University of Science and Technology, NT
#  #############
# Iteration 1020, output === https://ror.org/03avf6522 // name===Norwegian Polar Institute, Longyearbyen
#  #############
# Iteration 1021, output === https://ror.org/03avf6522 // name===Norwegian Polar Institute, Ny-Ålesund
#  #############
# Iteration 1022, output === https://ror.org/03cyjf656 // name===University Courses on Svalbard
#  #############
# Iteration 1023, output === https://ror.org/057ff4y42 // name===Department of Zoology, Universität Wien
#  #############
# Iteration 1024, output === https://ror.org/0406s2v03 // name===Maritime Branch, Institute of Meteorology and Water Management
#  #############
# Iteration 1025, output === https://ror.org/02a5meq09 // name===Centre for Biology of the Sea of the Polish Academy of Sciences
#  #############
# Iteration 1026, output === https://ror.org/03x3g5758 // name===Sea Fisheries Institute, Morski Insytut Rybacki, Gdynia
#  #############
# Iteration 1027, output === https://ror.org/019sbgd69 // name===Institute of Oceanography, University of Gdansk
#  #############
# Iteration 1028, output === wrong input type! // name===Marine Institute, Gdansk / Poland
#  #############
# Iteration 1029, output === https://ror.org/05kff3e67 // name===Hel Marine Biolocial Station
#  #############
# Iteration 1030, output === https://ror.org/02a5meq09 // name===Institute of Oceanology of the Polish Acedemy of Sciences
#  #############
# Iteration 1031, output === https://ror.org/03x3g5758 // name===Sea Fisheries Institute, Morski Insytut Rybacki, Swinoujscie
#  #############
# Iteration 1032, output === https://ror.org/04ejdtr48 // name===Polish American Centre of Sorting Plankton, Sea Fisheries Institute, Szczecin
#  #############
# Iteration 1033, output === https://ror.org/02sj9tq04 // name===Institute of Navigation & Marine Fisheries, Maritime University in Szczecin
#  #############
# Iteration 1034, output === https://ror.org/03v1svm63 // name===University of Agriculture
#  #############
# Iteration 1035, output === https://ror.org/02bt0vt04 // name===Department of Marine Ecology and Environmental Protection, University of Agricul
#  #############
# Iteration 1036, output === https://ror.org/03v1svm63 // name===Department of Oceanography, University of Agriculture
#  #############
# Iteration 1037, output === https://ror.org/04276xd64 // name===Departmento de Biologia, Universidade Açores
#  #############
# Iteration 1038, output === https://ror.org/04276xd64 // name===Departmento de Oceanografica e Pescas, Universidade Açores
#  #############
# Iteration 1039, output === https://ror.org/007qsya74 // name===Instituto Portuges de Investigaçao Maritima, C. Reg. de Invest. Maritima-Norte
#  #############
# Iteration 1040, output === https://ror.org/00nt41z93 // name===Universidade Aveiro
#  #############
# Iteration 1041, output === https://ror.org/00nt41z93 // name===Departament de Biologia, Universidade Aveiro
#  #############
# Iteration 1042, output === https://ror.org/04032fz76 // name===Laboratorio Maritimo da Guia Forte de Nossa Senhora da Guia, Universidade de Lis
#  #############
# Iteration 1043, output === https://ror.org/014837179 // name===Faculdade de Ciencias e Tectnologia - Instituto do Mar, Universidade de Coimbra
#  #############
# Iteration 1044, output === https://ror.org/02gyps716 // name===Department de Biologia e Ecologia, Instituto do Mar, Universidade de Evora
#  #############
# Iteration 1045, output === https://ror.org/038dty275 // name===Centre for Marine and Environmental Research (CIMA), Algarve University, Faro, Portugal
#  #############
# Iteration 1046, output === https://ror.org/014g34x36 // name===Centro de Ecologia e Aquaculturia, Universidade Algarve (E Mac)
#  #############
# Iteration 1047, output === https://ror.org/014g34x36 // name===Unidade de Ciencias e Technologias dos Recursos Aquaticos, Universidade Algarve
#  #############
# Iteration 1048, output === https://ror.org/00q6d2f90 // name===Regiao Autónoma da Madeira, Direcço Regional das Pescas
#  #############
# Iteration 1049, output === https://ror.org/0213kp011 // name===Instituto Geologico Mineiro
#  #############
# Iteration 1050, output === https://ror.org/00fqrrm56 // name===Instituto Hidrografico, Lisboa
#  #############
# Iteration 1051, output === https://ror.org/01fqrjt38 // name===Instituto Nacional de Meterologia e Geofisica
#  #############
# Iteration 1052, output === https://ror.org/04ea70f07 // name===Instituto Portuges de Investigaçao Maritima, Lisboa
#  #############
# Iteration 1053, output === https://ror.org/01sp7nd78 // name===Instituto do Mar, Instituto Superior Tecnico
#  #############
# Iteration 1054, output === https://ror.org/04ea70f07 // name===Department of Mechanical Engineering, Instituto Superior Tecnico
#  #############
# Iteration 1055, output === https://ror.org/01ryrwk91 // name===Secça Autónoma de Engenharia Naval
#  #############
# Iteration 1056, output === https://ror.org/03bvw9g02 // name===Laboratorio Nacional Engenharia Civil
#  #############
# Iteration 1057, output === https://ror.org/03bvw9g02 // name===Azinhaga dos Lameiros, Laboratório Nacional de Engenharia e Tecnologia Industria
#  #############
# Iteration 1058, output === https://ror.org/01hnx4w34 // name===Museu e Laboratorio Zoologico Antropologico, Museu Bocage
#  #############
# Iteration 1059, output === https://ror.org/00zjprf31 // name===Faculdade de Ciencias, Universidade de Lisboa
#  #############
# Iteration 1060, output === https://ror.org/02y9x6z24 // name===Centro de Oceanografia, Departmento de Fisica, Centro de Geofisica, Universidade
#  #############
# Iteration 1061, output === https://ror.org/01sp7nd78 // name===Departmento de Zoologia, Instituto do Mar
#  #############
# Iteration 1062, output === https://ror.org/014837179 // name===Instituto do Mar, Faculdade de Ciencias e Tecnologicia, Universidade Nova de Lis
#  #############
# Iteration 1063, output === https://ror.org/007qsya74 // name===Instituto Portuges de Investigaçao Maritima, C. Reg. de Invest. Maritima-Sul
#  #############
# Iteration 1064, output === https://ror.org/05v384f19 // name===Instituto do Mar, Universidade do Porto
#  #############
# Iteration 1065, output === https://ror.org/04ehtgm24 // name===Instituto de Ciéncias Biomédicas Abel Salazar, Universidade do Porto
#  #############
# Iteration 1066, output === https://ror.org/04ehtgm24 // name===Faculdade de Ciencias, Universidade do Porto
#  #############
# Iteration 1067, output === https://ror.org/048ppb911 // name===Romanian Center of Marine Geology and Geo-Ecology, Bucharest
#  #############
# Iteration 1068, output === https://ror.org/0005tvh12 // name===National Institute of Meteorology and Hydrology, Bucharest
#  #############
# Iteration 1069, output === https://ror.org/03d187f57 // name===Environmental Research and Engineering Institute, Bucharest
#  #############
# empty response!
# Iteration 1070, output === None // name===Aquaproject S.A.
#  #############
# Iteration 1071, output === https://ror.org/0561n6946 // name===Romanian Marine Research Institute
#  #############
# Iteration 1072, output === https://ror.org/02vsz1415 // name===Romania Center of Marine Geology and Geo-Ecology
#  #############
# Iteration 1073, output === https://ror.org/005m99512 // name===Research Laboratory for Aquaculture and Aquatic Ecology
#  #############
# Iteration 1074, output === https://ror.org/018afr131 // name===Institute of Marine Fisheries & Oceanography, M.N.Knipovitch Pol Res Arkhangelsk
#  #############
# Iteration 1075, output === https://ror.org/056wf8856 // name===Kola Science Centre Russian Acedemy of Sciences Marine Fisheries and Oceanograph
#  #############
# Iteration 1076, output === wrong input type! // name===Atlantic Scientific Research Institute of Marine Fisheries and Oceanography (Atl
#  #############
# Iteration 1077, output === https://ror.org/0577sef82 // name===A.A. Severtsov Institute of Problems of Ecology and Evolution
#  #############
# Iteration 1078, output === https://ror.org/04y9x6j75 // name===All-Russian Research Institute of Geological, Geophysical and Geochemical System
#  #############
# Iteration 1079, output === https://ror.org/053t6pj86 // name===Department of Marine and Ecological Research, Ministry of Science and Technology
#  #############
# Iteration 1080, output === https://ror.org/010pmpe69 // name===Department of Oceanology, M.V. Lomonosov Moscow State University
#  #############
# Iteration 1081, output === https://ror.org/00apb0c64 // name===Russian Federal Research Institute of Fisheries and Oceanography, Moscow
#  #############
# Iteration 1082, output === https://ror.org/05qrfxd25 // name===Geological Institute, Russian Academy of Sciences, Moscow
#  #############
# Iteration 1083, output === https://ror.org/053pwmv60 // name===V.I. Vernadsky Institute of Geochemistry and Analytical Chemistry, Russian Academy of Sciences, Moscow
#  #############
# Iteration 1084, output === https://ror.org/0302zgk11 // name===State Oceanographic Institute, Moscow
#  #############
# Iteration 1085, output === https://ror.org/01ww2bg72 // name===Arctic seas oil and gas prospecting
#  #############
# Iteration 1086, output === https://ror.org/00hqnxt08 // name===Institute of Marine Fisheries & Oceanography, M.N.Knipovitch Pol Res Murmansk
#  #############
# Iteration 1087, output === https://ror.org/00hqnxt08 // name===Murmansk Research Institute for Marine Geophysics
#  #############
# Iteration 1088, output === https://ror.org/03ttsq905 // name===Murmansk State Academy of Marketable Fishery Fleet
#  #############
# Iteration 1089, output === https://ror.org/050vepj62 // name===The Arctic Marine Engineering an Geological Expeditions
#  #############
# Iteration 1090, output === https://ror.org/019j3tz70 // name===Northseas Oil Geophysics
#  #############
# Iteration 1091, output === https://ror.org/0338jc112 // name===A.A. Ukhtomsky Research Institute of Physiology, St. Petersburg State University
#  #############
# Iteration 1092, output === https://ror.org/04s87ky63 // name===A.P. Karpinsky Scientific Research Geological Institute, St. Petersburg
#  #############
# Iteration 1093, output === https://ror.org/04k5dj193 // name===Northern Research and Production Association for Marine Geological Prospecting W
#  #############
# Iteration 1094, output === https://ror.org/018afr131 // name===Polar Marine Geologcial Survey Expedition
#  #############
# Iteration 1095, output === https://ror.org/048kbkr42 // name===Faculty of Oceanology, Russia State Hydrometeorogical Institute
#  #############
# Iteration 1096, output === https://ror.org/05960ca78 // name===Zoologcial Institute, Russian Academy of Science
#  #############
# Iteration 1097, output === https://ror.org/03fgw4s80 // name===Laboratory of Marine Research
#  #############
# Iteration 1098, output === https://ror.org/030h9s280 // name===Russian Navy Department of Navigation and Oceanography, St. Petersburg
#  #############
# Iteration 1099, output === https://ror.org/04d7gd791 // name===Ecological and Standardisation and Monitoring Laboratory, St. Petersburg Technic
#  #############
# Iteration 1100, output === https://ror.org/023znxa73 // name===Faculty of Geography and Geoecology, Saint Petersburg University Divisio
#  #############
# Iteration 1101, output === https://ror.org/008cjy335 // name===Scientific and Research Institute of Industrial and Marine Medicine, St. Petersb
#  #############
# Iteration 1102, output === https://ror.org/05tnvgk65 // name===Northern State Enterprise on Marine Geologcial Works
#  #############
# Iteration 1103, output === https://ror.org/050vepj62 // name===State Research Institute of Environmental Protection of the Arctic and the North
#  #############
# Iteration 1104, output === https://ror.org/01fe6wg83 // name===All-Russian Research Institute for Geology and Mineral Resources of the World Ocean, St. Petersburg
#  #############
# Iteration 1105, output === https://ror.org/02bjhwk41 // name===Academy of Ecological Sciences of the Republic of Georgia
#  #############
# Iteration 1106, output === https://ror.org/000nnmz85 // name===Administration of Hydrometeorology and Environment Monitoring Beradez
#  #############
# Iteration 1107, output === https://ror.org/00k6ffj36 // name===Scientific Centre of Radiobiology and Radiation Ecology
#  #############
# Iteration 1108, output === https://ror.org/05skxzn48 // name===Georgian National Oceanographic Committee - Khomeriki
#  #############
# Iteration 1109, output === https://ror.org/05fd1hd85 // name===Cartography and Geoinformation Faculty of Tbilisi State University
#  #############
# Iteration 1110, output === https://ror.org/007zp0p53 // name===Institute of Cemical Technology
#  #############
# Iteration 1111, output === https://ror.org/03rxyzb74 // name===Research Institute of Hygiene and Epidemiology
#  #############
# Iteration 1112, output === https://ror.org/03g9v2404 // name===Faculty of Natural Sciences Analytical Chemistry Chair, Tirana University
#  #############
# Iteration 1113, output === https://ror.org/03rxyzb74 // name===Organic Chemistry Chair Laboratory for Organic Instrumental Analysis Bulervardi
#  #############
# Iteration 1114, output === https://ror.org/03s5t0r17 // name===National Institute of Biology, Piran
#  #############
# Iteration 1115, output === https://ror.org/04fj80m50 // name===Geologisches Institut, Universität Basel
#  #############
# Iteration 1116, output === https://ror.org/029pk6x14 // name===Husö Biological Station, Åbo Academy University
#  #############
# Iteration 1117, output === https://ror.org/03vjnqy43 // name===Geological Survey of Finland
#  #############
# Iteration 1118, output === https://ror.org/03yj89h83 // name===Perämeri Research Station, Marjaniemi Field Station, University of Oulu
#  #############
# Iteration 1119, output === https://ror.org/040af2s02 // name===Tväminne Zoological Station, University of Helsinki
#  #############
# Iteration 1120, output === https://ror.org/05hppb561 // name===Headquartetrs and Aquaculture & Fisheries Division, Finnish Institute of Game an
#  #############
# Iteration 1121, output === https://ror.org/013nat269 // name===Finnish Environment Institute
#  #############
# Iteration 1122, output === https://ror.org/03k90y290 // name===Finnish Institute of Marine Research, Helsinki
#  #############
# Iteration 1123, output === https://ror.org/03vjnqy43 // name===Hydrographic Survey Division
#  #############
# Iteration 1124, output === https://ror.org/036bxpj43 // name===Department of Limnology and Environmental Protection Section of Limnology, Unive
#  #############
# Iteration 1125, output === https://ror.org/01j45tp19 // name===Karelian Institute Section of Ecology, University of Joensuu
#  #############
# Iteration 1126, output === https://ror.org/01zv3gf04 // name===Åland Research Station, Finnish Institute of Game and Fisheries Research
#  #############
# Iteration 1127, output === https://ror.org/05vghhr25 // name===Archipelago Sea Research Institute (summer), University of Turku
#  #############
# Iteration 1128, output === https://ror.org/03yj89h83 // name===University of Oulu
#  #############
# Iteration 1129, output === https://ror.org/01zv3gf04 // name===Finnish Institute of Game and Fisheries Research, Peråmeri Field Station
#  #############
# Iteration 1130, output === https://ror.org/029pk6x14 // name===Information Office, Åbo Academy
#  #############
# Iteration 1131, output === https://ror.org/05qn8wt84 // name===Institute pf Parasitology, BIOCITY
#  #############
# Iteration 1132, output === https://ror.org/05vghhr25 // name===Department of Biology, Section of Ecology and Systematics, University of Turku
#  #############
# Iteration 1133, output === https://ror.org/05vghhr25 // name===University of Turku
#  #############
# Iteration 1134, output === https://ror.org/01zv3gf04 // name===Northern Quark Research Station, Finnish Institute of Game and Fisheries Researc
#  #############
# Iteration 1135, output === https://ror.org/000ncdv93 // name===Salmon Research Institute, National Board of Fisheries
#  #############
# Iteration 1136, output === https://ror.org/00q1c3610 // name===Marine Research Station at Kristineberg, Kristinebergs Marina Forskningsstation
#  #############
# Iteration 1137, output === https://ror.org/0442ywx89 // name===Göteborg Center for Marine Research, University of Göteborg
#  #############
# Iteration 1138, output === https://ror.org/000ncdv93 // name===National Board of Fisheries, Göteborg
#  #############
# Iteration 1139, output === https://ror.org/00x2kxt49 // name===Institutet för Naturvetenskap, Kalmarsunds Laboratoriet
#  #############
# Iteration 1140, output === https://ror.org/000ncdv93 // name===Baltic Sea Research Station, National Board of Fisheries
#  #############
# Iteration 1141, output === https://ror.org/000ncdv93 // name===Institute of Marine Research, National Board of Fisheries
#  #############
# Iteration 1142, output === https://ror.org/000ncdv93 // name===Institute of Coastal Fisheries Research, National Board of Fisheries
#  #############
# Iteration 1143, output === https://ror.org/05f0yaq80 // name===Stockholm Center for Marine Research, University of Stockholm
#  #############
# Iteration 1144, output === https://ror.org/02y7nf053 // name===Division of Marine Research, National Environmental Protection Board
#  #############
# Iteration 1145, output === https://ror.org/05f0yaq80 // name===Department of Zoology, University of Stockholm
#  #############
# Iteration 1146, output === https://ror.org/033khx691 // name===Tjärnö Marine Biological Laboratory
#  #############
# Iteration 1147, output === https://ror.org/04ev03g22 // name===Askö Laboratory
#  #############
# Iteration 1148, output === https://ror.org/05kb8h459 // name===Umeå University Marina Sciences Center, University of Umeå
#  #############
# Iteration 1149, output === https://ror.org/02yy8x990 // name===Department of Aquaculture, Swedish University of Agricultural Sciences
#  #############
# Iteration 1150, output === https://ror.org/048a87296 // name===Department of Zoology, University of Uppsala
#  #############
# Iteration 1151, output === https://ror.org/050rtva22 // name===Division of Marine Geology, Geological Survey of Sweden
#  #############
# Iteration 1152, output === https://ror.org/00hgzve81 // name===Swedish Meteorological and Hydrological Institute
#  #############
# Iteration 1153, output === https://ror.org/00aqt9352 // name===Institute of Marine Sciences and Geography, University of Instanbul
#  #############
# Iteration 1154, output === https://ror.org/05syseh24 // name===Naval Hydrography and Oceanography Department, Turkish Navy
#  #############
# Iteration 1155, output === wrong input type! // name===Southern Scientific Research Institut of Marine Fisheries and Oceanography (YugN
#  #############
# Iteration 1156, output === https://ror.org/04ev01y75 // name===National Agency of Marine Research and Technology
#  #############
# Iteration 1157, output === https://ror.org/001561737 // name===State Scientific and Research Enterprise Ukraukflot
#  #############
# Iteration 1158, output === https://ror.org/0303yjn29 // name===Ukrainian Scientific Center of Marine Ecology, Odessa
#  #############
# Iteration 1159, output === https://ror.org/01188mx28 // name===Hydroacoustics Department, Marine Hydrophysical Institute
#  #############
# Iteration 1160, output === https://ror.org/03qf4s180 // name===Institute of Biology of the Southern Seas, National Academy of Sciences of Ukraine, Sevastopol
#  #############
# Iteration 1161, output === https://ror.org/00je4t102 // name===Marine Hydrophysical Institute, National Academy of Sciences of Ukraine
#  #############
# Iteration 1162, output === https://ror.org/05b7yq612 // name===Scientific and Industrial Enterprise "Mariecoprom"
#  #############
# Iteration 1163, output === https://ror.org/02kh2f959 // name===Marine Laboratory, Department of Agriculture and Fisheries for Scotland, Aberdeen
#  #############
# Iteration 1164, output === https://ror.org/016476m91 // name===Culterty Field Station, University of Aberdeen
#  #############
# Iteration 1165, output === https://ror.org/016476m91 // name===Department of Zoology, University of Aberdeen
#  #############
# Iteration 1166, output === https://ror.org/01zctcs90 // name===Petroleum Studies, Marischal College
#  #############
# Iteration 1167, output === https://ror.org/02gez1e74 // name===Biochemistry Department, Marischal College
#  #############
# Iteration 1168, output === https://ror.org/01se4f844 // name===Department of Geology, University of Wales, Aberystwyth
#  #############
# Iteration 1169, output === https://ror.org/01fyqq855 // name===Marine Farming Unit, Sea Fish Industry Authority
#  #############
# Iteration 1170, output === https://ror.org/006jb1a24 // name===School of Ocean Sciences, University College of North Wales (University College)
#  #############
# Iteration 1171, output === https://ror.org/057dddr91 // name===Department of Agriculture, Northern Ireland, Aquatic Sciences Research Division
#  #############
# Iteration 1172, output === https://ror.org/002g3cb31 // name===Queen´s University of Belfast
#  #############
# Iteration 1173, output === https://ror.org/00tw3jy02 // name===Department of Biology, Queen University of Belfast
#  #############
# Iteration 1174, output === https://ror.org/02veezx93 // name===Proudman Oceanographic Laboratory, Merseysi
#  #############
# Iteration 1175, output === https://ror.org/01ch2yn61 // name===Meteorological Office, Hadley Centre for Climate Prediction and Research
#  #############
# Iteration 1176, output === https://ror.org/00vs8d940 // name===Department of Civil Engineering , University of Bradford
#  #############
# Iteration 1177, output === https://ror.org/01zewfb16 // name===Environment Agency
#  #############
# Iteration 1178, output === https://ror.org/0524sp257 // name===Department of Mathematics, University of Bristol
#  #############
# Iteration 1179, output === https://ror.org/0021w4337 // name===Fisheries Laboratory, Ministry of Agriculture, Fisheries and Food, Burnham-on-Crouch
#  #############
# Iteration 1180, output === https://ror.org/03sbpja79 // name===Department of Applied Mathematics and Theoretical Physics, University of Cambrid
#  #############
# Iteration 1181, output === https://ror.org/01zewfb16 // name===H.Q. Fisheries and Conservation Department, Environment Agency Welsh Region
#  #############
# Iteration 1182, output === https://ror.org/01se4f844 // name===Department of Maritime Studies, University of Wales, Institute of Science & Tech
#  #############
# Iteration 1183, output === wrong input type! // name===Fisheries Research Laboratory, Department of Agriculture for Northern Ireland (D
#  #############
# Iteration 1184, output === https://ror.org/0021w4337 // name===Fisheries Laboratory, Ministry of Agriculture, Fisheries and Food, Conwy
#  #############
# Iteration 1185, output === https://ror.org/043j90n04 // name===RVAS Aquatic Resources Unit
#  #############
# Iteration 1186, output === https://ror.org/03h2bxq36 // name===Department of Civil Engineering, University of Dundee
#  #############
# Iteration 1187, output === https://ror.org/04a7gbp98 // name===British Geological Survey, Edinburgh
#  #############
# Iteration 1188, output === https://ror.org/04mghma93 // name===Civil Engineering Department, Heriot-Watt University, Research Park Riccarton
#  #############
# Iteration 1189, output === https://ror.org/04mghma93 // name===Department of Biological Sciences, Heriot-Watt University, Research Park Riccart
#  #############
# Iteration 1190, output === https://ror.org/04mghma93 // name===Institute of Offshore Engineering Research Park Riccarton, Heriot-Watt Universit
#  #############
# Iteration 1191, output === https://ror.org/01fyqq855 // name===Seafish Industry Aufhority
#  #############
# Iteration 1192, output === https://ror.org/01nrxwf90 // name===Department of Meteorology, Edinburgh
#  #############
# Iteration 1193, output === https://ror.org/00vtgdb53 // name===Department of Naval Architecture & Ocean Engineering, University of Glasgow
#  #############
# Iteration 1194, output === https://ror.org/00vtgdb53 // name===Microbiology Department, University of Glasgow
#  #############
# Iteration 1195, output === https://ror.org/00tw3jy02 // name===Department of Molecular and Cell Biology, University of Glasgow
#  #############
# Iteration 1196, output === https://ror.org/00vtgdb53 // name===Zoology Department, University of Glasgow
#  #############
# Iteration 1197, output === https://ror.org/00n3w3b69 // name===Department of Statistics and Modelling Science, University of Strathclyde
#  #############
# Iteration 1198, output === https://ror.org/01fyqq855 // name===Seafish Technology, Sea Fish Industry Aufhority
#  #############
# Iteration 1199, output === https://ror.org/04nkhwh30 // name===Humberside International, Fisheries Institute, University of Hull
#  #############
# Iteration 1200, output === https://ror.org/04nkhwh30 // name===Department of Estuarine & Coastal Studies, University of Hull
#  #############
# Iteration 1201, output === https://ror.org/04xs57h96 // name===Port Erin Marine Laboratory, University of Liverpool
#  #############
# Iteration 1202, output === https://ror.org/024mrxd33 // name===Department of Electronic and Electrical Engineering, University of Leeds
#  #############
# Iteration 1203, output === https://ror.org/04xs57h96 // name===Department of Earth Sciences, Oceanography Laboratory, University of Liverpool
#  #############
# Iteration 1204, output === https://ror.org/04xs57h96 // name===Oceanography Laboratories, University of Liverpool
#  #############
# Iteration 1205, output === https://ror.org/04xs57h96 // name===Department of Geography, University of Liverpool
#  #############
# Iteration 1206, output === https://ror.org/00k66f384 // name===Marine Resources Assessment Group Ltd., London
#  #############
# Iteration 1207, output === https://ror.org/039zvsn29 // name===Department of Zoology, Natural History Museum
#  #############
# Iteration 1208, output === https://ror.org/02pvnr704 // name===Office of Science and Technology
#  #############
# Iteration 1209, output === https://ror.org/026zzn846 // name===Queen Mary and Westfield College, Centre for Research in Aquatic Biology, Univer
#  #############
# Iteration 1210, output === https://ror.org/04r7rxc53 // name===The Centre for Environment Fisheries and Aquaculture Science, Lowestoft
#  #############
# Iteration 1211, output === https://ror.org/02kh2f959 // name===University Marine Biologcial Station
#  #############
# Iteration 1212, output === https://ror.org/01kj2bm70 // name===Dove Marine Laboratory, University of Newcastle upon Tyne
#  #############
# Iteration 1213, output === https://ror.org/026k5mg93 // name===School of Mathematics, University of East Anglia
#  #############
# Iteration 1214, output === https://ror.org/04ke6ht85 // name===Scottish Association for marine Science, Argyll
#  #############
# Iteration 1215, output === https://ror.org/052gg0110 // name===Department of Engineering Science, University of Oxford
#  #############
# Iteration 1216, output === https://ror.org/05tzsrw37 // name===Marine Conservation Branch, Joint Nature Conservation Committee, Peterborough
#  #############
# Iteration 1217, output === https://ror.org/0431sk359 // name===Marine Biological Association of the U.K , Plymouth
#  #############
# Iteration 1218, output === https://ror.org/01b1y2d10 // name===Sir Alister Hardy Foundation for Ocean Science
#  #############
# Iteration 1219, output === https://ror.org/05av9mn02 // name===Institute of Marine Studies, University of Plymouth
#  #############
# Iteration 1220, output === https://ror.org/008n7pv89 // name===Department of Environmental Science, University of Plymouth
#  #############
# Iteration 1221, output === https://ror.org/03ykbk197 // name===Marine Resources Research Unit, University of Portsmouth
#  #############
# Iteration 1222, output === https://ror.org/03ykbk197 // name===Marine Laboratory, University of Portsmouth
#  #############
# Iteration 1223, output === https://ror.org/02b5d8509 // name===Challenger Division for Seafloor Processes, Natural Environment Research Council
#  #############
# Iteration 1224, output === https://ror.org/02b5d8509 // name===George Deacon Division for Ocean Processes, Natural Environment Research Council
#  #############
# Iteration 1225, output === https://ror.org/02b5d8509 // name===James Rennell Division for Ocean Circulation, Natural Environment Research Counc
#  #############
# Iteration 1226, output === https://ror.org/02b5d8509 // name===Research Vessel Services, Natural Environment Research Council
#  #############
# Iteration 1227, output === https://ror.org/01ryk1543 // name===Department of Oceanography, University of Southampton
#  #############
# Iteration 1228, output === https://ror.org/01ryk1543 // name===Department of Geology, University of Southampton
#  #############
# Iteration 1229, output === https://ror.org/02bn4n710 // name===Faculty of Engineering: Marine Technology and Underwater Acoustics, University o
#  #############
# Iteration 1230, output === https://ror.org/01ryk1543 // name===Department of Biology, University of Southampton
#  #############
# Iteration 1231, output === https://ror.org/02wn5qz54 // name===Gatty Marine Laboratory, University of St. Andrews
#  #############
# Iteration 1232, output === https://ror.org/02wn5qz54 // name===Gatty Marine Laboratory, Sea Mammal Research Unit, St. Andrews
#  #############
# Iteration 1233, output === https://ror.org/045wgfr59 // name===Institute of Aquaculture, University of Stirling
#  #############
# Iteration 1234, output === https://ror.org/045wgfr59 // name===School of Natural Sciences, University of Stirling, Unit of Aquatic Biochemistry
#  #############
# Iteration 1235, output === https://ror.org/053fq8t95 // name===University of Wales, Swansea
#  #############
# Iteration 1236, output === https://ror.org/01se4f844 // name===School of Biological Sciences, University of Wales, Swansea
#  #############
# Iteration 1237, output === https://ror.org/02b5d8509 // name===Marine Science and Technology Board, Natural Environment Research Council, Swind
#  #############
# Iteration 1238, output === https://ror.org/05k0e7y54 // name===Institute of Hydrology, Wallingford Oxfordshire
#  #############
# Iteration 1239, output === https://ror.org/05ab5dj79 // name===Fish Diseases Laboratory, Ministry of Agriculture, Fisheries and Food, Weymouth
#  #############
# Iteration 1240, output === https://ror.org/01vhnrs90 // name===Max-Planck-Institut für Astronomie
#  #############
# Iteration 1241, output === https://ror.org/0243gzr89 // name===Max-Planck-Institut für Biologie, Tübingen
#  #############
# Iteration 1242, output === https://ror.org/022jc0g24 // name===Max-Planck-Institut für Entwicklungsbiologie
#  #############
# Iteration 1243, output === https://ror.org/005bk2339 // name===Max-Planck-Institut für Festkörperforschung
#  #############
# Iteration 1244, output === https://ror.org/04vh1tq58 // name===Friedrich-Miescher-Laboratorium für biologische Arbeitsgruppen in der Max-Planck
#  #############
# Iteration 1245, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Immunbiologie
#  #############
# Iteration 1246, output === https://ror.org/052d0h423 // name===Max-Planck-Institut für Kernphysik
#  #############
# Iteration 1247, output === https://ror.org/026nmvv73 // name===Max-Planck-Institut für Kybernetik
#  #############
# Iteration 1248, output === https://ror.org/000bxzc63 // name===Max-Planck-Institut für medizinische Forschung
#  #############
# Iteration 1249, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Metallforschung
#  #############
# Iteration 1250, output === https://ror.org/04a8rd767 // name===Max-Planck-Institut für ausländisches und internationales Strafrecht
#  #############
# Iteration 1251, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Verhaltensphysiologie Vogelwarte Radolfzell
#  #############
# Iteration 1252, output === https://ror.org/0515m2n86 // name===Max-Planck-Institut für ausländisches öffentliches Recht und Völkerrecht
#  #############
# Iteration 1253, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Zellbiologie
#  #############
# Iteration 1254, output === https://ror.org/017qcv467 // name===Max-Planck-Institut für Astrophysik
#  #############
# Iteration 1255, output === https://ror.org/04py35477 // name===Max-Planck-Institut für Biochemie, Martinsried
#  #############
# Iteration 1256, output === https://ror.org/023ahcz89 // name===Max-Planck-Institut für ausländisches und internationales Patent-, Urheber- und
#  #############
# Iteration 1257, output === https://ror.org/0079jjr10 // name===Max-Planck-Institut für Physik, Werner-Heisenberg-Institut
#  #############
# Iteration 1258, output === https://ror.org/00e4bwe12 // name===Max-Planck-Institut für extraterrestrische Physik
#  #############
# Iteration 1259, output === https://ror.org/04dq56617 // name===Max-Planck-Institut für Psychiatrie, Theoretisches Institut
#  #############
# Iteration 1260, output === https://ror.org/04dq56617 // name===Max-Planck-Institut für Psychiatrie, Klinisches Institut
#  #############
# Iteration 1261, output === https://ror.org/000bxzc63 // name===Max-Planck-Institut für psychologische Forschung
#  #############
# Iteration 1262, output === https://ror.org/01vekys64 // name===Max-Planck-Institut für Quantenoptik
#  #############
# Iteration 1263, output === https://ror.org/023ahcz89 // name===Max-Planck-Institut für ausländisches und internationales Sozialrecht
#  #############
# Iteration 1264, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Verhaltensphysiologie
#  #############
# Iteration 1265, output === https://ror.org/02pp7px91 // name===Max-Planck-Institut für Bildungsforschung
#  #############
# Iteration 1266, output === https://ror.org/03k9qs827 // name===Fritz-Haber-Institut der Max-Planck-Gesellschaft
#  #############
# Iteration 1267, output === https://ror.org/03ate3e03 // name===Max-Planck-Institut für molekulare Genetik
#  #############
# Iteration 1268, output === https://ror.org/0046gcs23 // name===Max-Planck-Institut für Infektionsbiologie
#  #############
# Iteration 1269, output === https://ror.org/0492sjc74 // name===Max-Planck-Institut für Wissenschaftsgeschichte
#  #############
# Iteration 1270, output === https://ror.org/03sry2h30 // name===Max-Planck-Institut für Gravitationsphysik, Albert-Einstein-Institut
#  #############
# Iteration 1271, output === https://ror.org/00pwgnh47 // name===Max-Planck-Institut für Kolloid- und Grenzfächenforschung
#  #############
# Iteration 1272, output === https://ror.org/01fbde567 // name===Max-Planck-Institut für molekulare Pflanzenphysiologie
#  #############
# Iteration 1273, output === https://ror.org/02385fa51 // name===Max-Planck-Institut für Marine Mikrobiologie
#  #############
# Iteration 1274, output === https://ror.org/023ahcz89 // name===Max-Planck-Institut für ausländisches und internationales Privatrecht
#  #############
# Iteration 1275, output === https://ror.org/02panr271 // name===Max-Planck-Institut für Biophysik, Frankfurt
#  #############
# Iteration 1276, output === https://ror.org/02h1nk258 // name===Max-Planck-Institut für Hirnforschung
#  #############
# Iteration 1277, output === https://ror.org/05r7n9c40 // name===Max-Planck-Institut für terrestrische Mikrobiologie
#  #############
# Iteration 1278, output === https://ror.org/02z95d405 // name===Max-Planck-Institut für physiologische und klinische Forschung, W.G. Kerckhoff-I
#  #############
# Iteration 1279, output === https://ror.org/00jpzvz45 // name===Max-Planck-Institut für europäische Rechtsgeschichte
#  #############
# Iteration 1280, output === https://ror.org/02jgyam08 // name===Max-Planck-Institut für demografische Forschung
#  #############
# Iteration 1281, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Aeronomie, Katlenburg-Lindau
#  #############
# Iteration 1282, output === https://ror.org/03e76ya46 // name===Max-Planck-Institut für biophysikalische Chemie, Karl-Friedrich-Bonhoeffer-Insti
#  #############
# Iteration 1283, output === https://ror.org/04a7f6w43 // name===Max-Planck-Institut für experimentelle Endokrinologie
#  #############
# Iteration 1284, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Geschichte
#  #############
# Iteration 1285, output === https://ror.org/04a7f6w43 // name===Max-Planck-Institut für experimentelle Medizin
#  #############
# Iteration 1286, output === https://ror.org/01vekys64 // name===Max-Planck-Institut für Quantenoptik, Gravitationswellenforschung
#  #############
# Iteration 1287, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Strömungsforschung
#  #############
# Iteration 1288, output === https://ror.org/01ngpvg12 // name===Max-Planck-Institut für Eisenforschung GmbH
#  #############
# Iteration 1289, output === https://ror.org/01dwpbz64 // name===Max-Planck-Institut für Gesellschaftsforschung
#  #############
# Iteration 1290, output === wrong input type! // name===Max-Planck-Institut für Kohlenforschung (rechtsfähige Stiftung), Mülheim/Ruhr
#  #############
# Iteration 1291, output === https://ror.org/02dh8ja68 // name===Max-Planck-Institut für Mathematik
#  #############
# Iteration 1292, output === https://ror.org/04vh1tq58 // name===Max-Delbrück-Laboratorium in der Max-Planck-Gesellschaft
#  #############
# Iteration 1293, output === https://ror.org/000bxzc63 // name===Max-Planck-Institut für neurologische Forschung
#  #############
# Iteration 1294, output === https://ror.org/03vpj4s62 // name===Max-Planck-Institut für molekulare Physiologie
#  #############
# Iteration 1295, output === https://ror.org/04jvemc39 // name===Max-Planck-Institut für Radioastronomie
#  #############
# Iteration 1296, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Strahlenchemie
#  #############
# Iteration 1297, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Züchtungsforschung
#  #############
# Iteration 1298, output === https://ror.org/02f5b7n18 // name===Max-Planck-Institut für Chemie, Otto-Hahn-Institut, Mainz
#  #############
# Iteration 1299, output === https://ror.org/00sb7hc59 // name===Max-Planck-Institut für Polymerforschung
#  #############
# Iteration 1300, output === https://ror.org/01w19ak89 // name===Max-Planck-Institut für Informatik
#  #############
# Iteration 1301, output === https://ror.org/00ez2he07 // name===Max-Planck-Institut für Mathematik in den Naturwissenschaften
#  #############
# Iteration 1302, output === https://ror.org/000bxzc63 // name===Max-Planck-Institut für neuropsychologische Forschung
#  #############
# Iteration 1303, output === https://ror.org/01bf9rw71 // name===Max-Planck-Institut für Physik komplexer Systeme
#  #############
# Iteration 1304, output === https://ror.org/01c997669 // name===Max-Planck-Institut für chemische Physik fester Stoffe
#  #############
# Iteration 1305, output === https://ror.org/0095xwr23 // name===Max-Planck-Institut für Mikrostrukturphysik
#  #############
# Iteration 1306, output === https://ror.org/03fkg8131 // name===Max-Planck-Institut für Limnologie
#  #############
# Iteration 1307, output === https://ror.org/02ks53214 // name===Max-Planck-Institut für chemische Ökologie, Jena
#  #############
# Iteration 1308, output === https://ror.org/02x1q2477 // name===Max-Planck-Institut zur Erforschung von Wirtschaftssystemen
#  #############
# Iteration 1309, output === https://ror.org/05qpz1x62 // name===Molekulare und zelluläre Biophysik, Universität Jena
#  #############
# Iteration 1310, output === https://ror.org/05qpz1x62 // name===Pharmakologische Hämostaseologie, Universität Jena
#  #############
# Iteration 1311, output === https://ror.org/04g6zen34 // name===Max-Planck-Institut, Bibliotheca Hertziana
#  #############
# empty response!
# Iteration 1312, output === None // name===Max-Planck-Institut für Psycholinguistik, Nimwegen
#  #############
# Iteration 1313, output === https://ror.org/01rvqha10 // name===Fraunhofer-Institut für Produktionstechnik und Automatisierung IPA
#  #############
# Iteration 1314, output === https://ror.org/0131dra29 // name===Fraunhofer-Institut für Grenzflächen- und Bioverfahrenstechnik IGB
#  #############
# Iteration 1315, output === https://ror.org/01nh64743 // name===Fraunhofer-Institut für Arbeitswirtschaft und Organisation IAO
#  #############
# Iteration 1316, output === https://ror.org/04y8p0f91 // name===Fraunhofer-Institut für Bauphysik IBP
#  #############
# Iteration 1317, output === https://ror.org/01yrp7892 // name===Fraunhofer-Institut für Raum und Bau IRB
#  #############
# Iteration 1318, output === https://ror.org/004n2nr09 // name===Fraunhofer-Institut für Physikalische Meßtechnik IPM
#  #############
# Iteration 1319, output === https://ror.org/04hm8eb66 // name===Fraunhofer-Institut für Werkstoffmechanik IWM
#  #############
# Iteration 1320, output === https://ror.org/02kfzvh91 // name===Fraunhofer-Institut für Solare Energiesysteme
#  #############
# Iteration 1321, output === https://ror.org/0083ncs46 // name===Fraunhofer-Institut für Angewandte Festkörperphysik IAF
#  #############
# Iteration 1322, output === https://ror.org/00csq2k70 // name===Fraunhofer-Institut für Kurzzeitdynamik-Ernst-Mach-Institut EMI
#  #############
# Iteration 1323, output === https://ror.org/03vyq6t71 // name===Fraunhofer-Institut für Systemtechnik und Innovationsforschung ISI
#  #############
# Iteration 1324, output === https://ror.org/04gmsar03 // name===Fraunhofer-Institut für Informations- und Datenverarbeitung IITB
#  #############
# Iteration 1325, output === https://ror.org/00bkxry42 // name===Fraunhofer-Institut für Chemische Technologie ICT
#  #############
# Iteration 1326, output === https://ror.org/02at7zv53 // name===Fraunhofer-Institut für Verfahrenstechnik und Verpackung IVV
#  #############
# Iteration 1327, output === https://ror.org/05dfnrn76 // name===Fraunhofer-Institut für Festkörpertechnologie IFT
#  #############
# Iteration 1328, output === https://ror.org/01yzfjx97 // name===Fraunhofer-Patentstelle für die Deutsche Forschung PST
#  #############
# Iteration 1329, output === https://ror.org/02cd1dc23 // name===Fraunhofer-Institut für Atomsphärische Umweltforschung IFU
#  #############
# Iteration 1330, output === https://ror.org/024ape423 // name===Fraunhofer-Institut für Integrierte Schaltungen IIS
#  #############
# Iteration 1331, output === https://ror.org/05gnv4a66 // name===Fraunhofer-Institut für Silikatforschung ISC
#  #############
# Iteration 1332, output === https://ror.org/058kjq542 // name===Fraunhofer-Arbeitsgruppe für Drahtlose Telekommunikations- und Multimediatechnik
#  #############
# Iteration 1333, output === https://ror.org/02fez3815 // name===Fraunhofer-Anwendungszentrum für Verkehrslogistik und Kommunikationstechnik AVK
#  #############
# Iteration 1334, output === https://ror.org/045eg9c12 // name===Fraunhofer-Institut für Produktionsanlagen und Konstruktionstechnik IPK
#  #############
# Iteration 1335, output === https://ror.org/058kjq542 // name===Fraunhofer-Institut für Software- und Systemtechnik ISST
#  #############
# Iteration 1336, output === https://ror.org/031aqk326 // name===Fraunhofer-Institut für Zuverlässigkeit und Mikrointegration, Berlin
#  #############
# Iteration 1337, output === https://ror.org/0083ncs46 // name===Fraunhofer-Institut für Angewandte Polymerforschung IAP
#  #############
# Iteration 1338, output === https://ror.org/031aqk326 // name===Fraunhofer-Institut für Zuverlässigkeit und Mikrointegration, Teltow
#  #############
# Iteration 1339, output === https://ror.org/058kjq542 // name===Fraunhofer-Institut für Umweltchemie und Ökotoxikologie IUCT, Bergholz-Rehbrücke
#  #############
# Iteration 1340, output === https://ror.org/058kjq542 // name===Fraunhofer-Anwendungszentrum für Entsorgungs- und Verkehrslogistik AEV des Fraun
#  #############
# Iteration 1341, output === https://ror.org/03pwyy961 // name===Fraunhofer-Institut für Fertigungstechnik und Materialforschung
#  #############
# Iteration 1342, output === https://ror.org/058kjq542 // name===Fraunhofer-Arbeitsgruppe für Toxikologie und Umweltmedizin ATU
#  #############
# Iteration 1343, output === https://ror.org/00gt16g40 // name===Fraunhofer-Institut für Betriebsfestigkeit LBF
#  #############
# Iteration 1344, output === https://ror.org/04gmsar03 // name===Fraunhofer-Institut für Graphische Datenverarbeitung IGD
#  #############
# Iteration 1345, output === https://ror.org/04gmsar03 // name===Fraunhofer-Institut für Graphische Datenverarbeitung IGD, Außenstelle Rostock EG
#  #############
# Iteration 1346, output === https://ror.org/058kjq542 // name===Fraunhofer-Institut für Toxikologie und Aerosolforschung ITA
#  #############
# Iteration 1347, output === https://ror.org/015cbgt79 // name===Fraunhofer-Institut für Holzforschung, Wilhelm-Klauditz-Institut WKI
#  #############
# Iteration 1348, output === https://ror.org/048vzmn57 // name===Fraunhofer-Institut für Schicht- und Oberflächentechnik IST
#  #############
# Iteration 1349, output === https://ror.org/01243c877 // name===Fraunhofer-Institut für Mikroelektronische Schaltungen und Systeme IMS
#  #############
# Iteration 1350, output === https://ror.org/00z7dje19 // name===Fraunhofer-Institut für Materialfluß und Logistik IML
#  #############
# Iteration 1351, output === https://ror.org/00t0rcy29 // name===Fraunhofer-Institut für Produktionstechnologie IPT
#  #############
# ...
#  #############
# Iteration 9269, output === https://ror.org/02s376052 // name===École Polytechnique Fédérale de Lausanne
#  #############
# Iteration 9270, output === https://ror.org/03cqe8w59 // name===National Scientific and Technical Research Council
#  #############
# Iteration 9271, output === https://ror.org/014g34x36 // name===Universidade do Algarve
#  #############
# Iteration 9272, output === TypeError occured while reading name or country // name===Department of Biosciences, Aarhus University, and Institute for Hydrobiology and Fisheries Science, University of Hamburg
#  #############
# Iteration 9273, output === https://ror.org/047272k79 // name===The University of Western Australia
#  #############
# Iteration 9274, output === TypeError occured while reading name or country // name===COSYNA - Helmholtz-Zentrum Geesthacht Zentrum für Material- und Küstenforschung GmbH
#  #############
# Iteration 9275, output === TypeError occured while reading name or country // name===Institute of Oceanology, Polish Academy of Sciences, Poland
#  #############
# Iteration 9276, output === https://ror.org/00zjprf31 // name===Instituto Geofísico do Infante D. Luiz, Universidade de Lisboa
#  #############
# Iteration 9277, output === https://ror.org/027m9bs27 // name===University of Manchester
#  #############
# Iteration 9278, output === https://ror.org/000xsnr85 // name===University of the Basque Country
#  #############
# Iteration 9279, output === https://ror.org/01xqdxh54 // name===South China Botanical Garden
#  #############
# Iteration 9280, output === TypeError occured while reading name or country // name===Office Environment and Heritage, Australia
#  #############
# Iteration 9281, output === TypeError occured while reading name or country // name===University of Colorado, Boulder
#  #############
# Iteration 9282, output === https://ror.org/02bsh9z73 // name===Curt-Engelhorn-Zentrum Archäometrie gGmbH
#  #############
# Iteration 9283, output === TypeError occured while reading name or country // name===College of Engineering, Mathematics and Physical Sciences, University of Exeter
#  #############
# Iteration 9284, output === TypeError occured while reading name or country // name===Presses universitaires de Rennes
#  #############
# Iteration 9285, output === https://ror.org/05wvpxv85 // name===Tufts University
#  #############
# Iteration 9286, output === TypeError occured while reading name or country // name===School of Environmental and Life Sciences, University of Newcastle, Australia
#  #############
# Iteration 9287, output === https://ror.org/037s24f05 // name===Clemson University, South Carolina
#  #############
# Iteration 9288, output === TypeError occured while reading name or country // name===Hydrographic and Oceanographic Department, Japan Coast Guard
#  #############
# Iteration 9289, output === https://ror.org/041yk2d64 // name===Universidade Federal do Rio Grande do Sul, Porto Alegre
#  #############
# Iteration 9290, output === https://ror.org/01m84wm78 // name===Laboratoire Archéosciences - Université Rennes
#  #############
# Iteration 9291, output === https://ror.org/04r2r8477 // name===Patrimoine historique et naturel des îles d'Hoedic et de Houat
#  #############
# Iteration 9292, output === TypeError occured while reading name or country // name===Brown University, Rhode Island
#  #############
# Iteration 9293, output === TypeError occured while reading name or country // name===National Centre for Antarctic and Ocean Research, Goa, India
#  #############
# Iteration 9294, output === https://ror.org/04qyvz380 // name===San José State University
#  #############
# Iteration 9295, output === https://ror.org/04z82ry91 // name===Marine and Coastal Resources Center
#  #############
# Iteration 9296, output === https://ror.org/05ykr0121 // name===Romberg Tiburon Center for Environmental Studies, San Francisco State University
#  #############
# Iteration 9297, output === https://ror.org/04bcrv494 // name===National Institute of Wind Energy
#  #############
# Iteration 9298, output === TypeError occured while reading name or country // name===CEG/IGOT, Universidade de Lisboa
#  #############
# Iteration 9299, output === https://ror.org/00v2d0427 // name===Rudolf Habelt Verlag
#  #############
# Iteration 9300, output === https://ror.org/01zg9j813 // name===Kessel Verlag
#  #############
# Iteration 9301, output === https://ror.org/02vt7ey12 // name===Ulster Archaeological Society
#  #############
# Iteration 9302, output === https://ror.org/00r1edq15 // name===Geographsches Institut der Ernst-Moritz-Arndt-Universität Greifswald
#  #############
# empty response!
# Iteration 9303, output === None // name===London and Middlesex Archaeological Society
#  #############
# Iteration 9304, output === TypeError occured while reading name or country // name===Department of Geography, University of Hull
#  #############
# Iteration 9305, output === https://ror.org/00d9ah105 // name===University of California, Merced
#  #############
# Iteration 9306, output === TypeError occured while reading name or country // name===Fujian Normal University, China
#  #############
# Iteration 9307, output === TypeError occured while reading name or country // name===Komi Science Centre of the Ural Division of the Russian Academy of Sciences
#  #############
# Iteration 9308, output === TypeError occured while reading name or country // name===Geophysical Institute, University of Alaska Fairbanks, USA
#  #############
# Iteration 9309, output === https://ror.org/05nywn832 // name===Department of Wildlife Diseases, Leibniz Institute for Zoo and Wildlife Research, Berlin, Germany
#  #############
# Iteration 9310, output === TypeError occured while reading name or country // name===German Aerospace Center (DLR)
#  #############
# Iteration 9311, output === https://ror.org/02af4h012 // name===Jadavpur University
#  #############
# Iteration 9312, output === https://ror.org/02qt0xs84 // name===Humboldt State University, CA
#  #############
# Iteration 9313, output === TypeError occured while reading name or country // name===Juniper Publishers
#  #############
# Iteration 9314, output === TypeError occured while reading name or country // name===Yale University
#  #############
# Iteration 9315, output === https://ror.org/03j9e2j92 // name===Naval Research Laboratory, Stennis Space Center
#  #############
# Iteration 9316, output === https://ror.org/01sbq1a82 // name===University of Delaware
#  #############
# Iteration 9317, output === https://ror.org/024wr7x07 // name===Department of Geophysics, Universidad de Chile
#  #############
# Iteration 9318, output === TypeError occured while reading name or country // name===University of Oxford
#  #############
# Iteration 9319, output === https://ror.org/00g0p6g84 // name===University of Pretoria, Mammal Research Institute
#  #############
# Iteration 9320, output === https://ror.org/002t25c44 // name===Sorbonne Université, Paris, France
#  #############
# Iteration 9321, output === https://ror.org/03yghzc09 // name===University of Exeter
#  #############
# Iteration 9322, output === https://ror.org/02a33b393 // name===Max Planck Institute for Evolutionary Anthropology
#  #############
# Iteration 9323, output === https://ror.org/03r8nwp71 // name===Universitatea din Cluj
#  #############
# Iteration 9324, output === TypeError occured while reading name or country // name===Canadian Science Publishing
#  #############
# empty response!
# Iteration 9325, output === None // name===Scottish Universities Environmental Research Centre
#  #############
# Iteration 9326, output === TypeError occured while reading name or country // name===European Commission, Joint Research Centre
#  #############
# Iteration 9327, output === https://ror.org/051xgzg37 // name===Department of Ecology, Environment and Plant Sciences, Stockholm University
#  #############
# Iteration 9328, output === TypeError occured while reading name or country // name===U.S. Army Corps of Engineers
#  #############
# Iteration 9329, output === https://ror.org/01zvw4x71 // name===Ministry of Ecology and Natural Resources of Ukraine
#  #############
# Iteration 9330, output === https://ror.org/006qkqr45 // name===Institute for Coastal Marine Environment, National Research Council
#  #############
# Iteration 9331, output === https://ror.org/0040zx077 // name===Istituto di ricerca per la Protezione Idrogeologica del Consiplio Nazionale delle Ricerche
#  #############
# Iteration 9332, output === https://ror.org/01jr63883 // name===Geographisches Institut, Universität Zürich
#  #############
# Iteration 9333, output === https://ror.org/03efzvv60 // name===IADO-CONICET Bahía Blanca
#  #############
# Iteration 9334, output === https://ror.org/013meh722 // name===Department of Geography, University of Cambridge
#  #############
# Iteration 9335, output === TypeError occured while reading name or country // name===Deutsche Seewarte
#  #############
# Iteration 9336, output === TypeError occured while reading name or country // name===Laboratorio di Urbanistica e di Pianificazione Territoriale - Raffaele d'Ambrosio
#  #############
# Iteration 9337, output === TypeError occured while reading name or country // name===Brookhaven National Laboratory
#  #############
# Iteration 9338, output === TypeError occured while reading name or country // name===Helmholtz-Zentrum Geesthacht Centre for Materials and Coastal Research, Alfred Wegener Institute, Carl von Ossietzky University Oldenburg
#  #############
# Iteration 9339, output === TypeError occured while reading name or country // name===University of Haifa
#  #############
# Iteration 9340, output === https://ror.org/01dg47b60 // name===Pontifical Catholic University of Rio de Janeiro
#  #############
# Iteration 9341, output === TypeError occured while reading name or country // name===Eurac Research
#  #############
# Iteration 9342, output === https://ror.org/01t04bt85 // name===TDI-Brooks
#  #############
# empty response!
# Iteration 9343, output === None // name===Institute of Geophysics of the Czech Academy of Sciences
#  #############
# Iteration 9344, output === https://ror.org/03rzp5127 // name===James Hutton Institute
#  #############
# Iteration 9345, output === TypeError occured while reading name or country // name===University of Cologne
#  #############
# Iteration 9346, output === https://ror.org/03gz4y884 // name===Laboratoire de Météorologie Physique
#  #############
# Iteration 9347, output === TypeError occured while reading name or country // name===Institute of Geography, University of Innsbruck
#  #############
# Iteration 9348, output === https://ror.org/0192yj155 // name===Key Laboratory of Ocean and Marginal Sea Geology, South China Sea Institute of Oceanology, Chinese Academy of Sciences
#  #############
# Iteration 9349, output === https://ror.org/017tgbk05 // name===Ecolab, University of Toulouse
#  #############
# Iteration 9350, output === TypeError occured while reading name or country // name===LAMP / CNRS / UCA / OPGC
#  #############
# Iteration 9351, output === TypeError occured while reading name or country // name===University of York, UK
#  #############
# Iteration 9352, output === TypeError occured while reading name or country // name===Laboratory for Observations and Analyses of Earth and Climate
#  #############
# Iteration 9353, output === https://ror.org/048eb3m59 // name===Meteorological Service Suriname
#  #############
# Iteration 9354, output === https://ror.org/05f0yaq80 // name===Department of Environmental Science and Analytical Chemistry, Stockholm University
#  #############
# Iteration 9355, output === https://ror.org/01s033b11 // name===School of Engineering, University of Glasgow
#  #############
# Iteration 9356, output === https://ror.org/03be3fb73 // name===National Measurement Institute Australia
#  #############
# Iteration 9357, output === https://ror.org/03dkyhy49 // name===Bio-Rad Laboratories, Inc.
#  #############
# Iteration 9358, output === https://ror.org/006g31f33 // name===Institute for Atmospheric Physics, University of Mainz
#  #############
# Iteration 9359, output === https://ror.org/01n4pqe45 // name===Agència de Gestió d'Ajuts Universitaris i de Recerca
#  #############
# Iteration 9360, output === https://ror.org/02p72h367 // name===University of Cincinnati
#  #############
# Iteration 9361, output === https://ror.org/05dnjaa32 // name===Instituto Geofisico del Peru
#  #############
# Iteration 9362, output === https://ror.org/04t3en479 // name===Karlsruhe Institute of Technology
#  #############
# Iteration 9363, output === https://ror.org/01v10fv91 // name===Instituto Tecnológico de Sonora
#  #############
# Iteration 9364, output === KeyError - query API error // name===Central Weather Bureau, Taiwan
#  #############
# Iteration 9365, output === https://ror.org/03ttqt747 // name===University of Montana
#  #############
# Iteration 9366, output === TypeError occured while reading name or country // name===Federal Ministry for Economic Affairs and Energy
#  #############
# Iteration 9367, output === TypeError occured while reading name or country // name===Institute of Geographic Sciences and Natural Resources Research, Chinese Academy of Sciences
#  #############
# Iteration 9368, output === TypeError occured while reading name or country // name===The Chinese University of Hong Kong
#  #############
# Iteration 9369, output === TypeError occured while reading name or country // name===University of Vienna
#  #############
# Iteration 9370, output === KeyError - query API error // name===Korea Institute of Ocean Science and Technology
#  #############
# Iteration 9371, output === https://ror.org/00vgt4p82 // name===Center for Earth System Research and Sustainability
#  #############
# Iteration 9372, output === https://ror.org/01d0fc168 // name===Integrated Carbon Observation System
#  #############
# Iteration 9373, output === TypeError occured while reading name or country // name===LTER-Austria – Gesellschaft für ökologische Langzeitforschung
#  #############
# Iteration 9374, output === TypeError occured while reading name or country // name===Chinese Academy of Meteorological Science
#  #############
# Iteration 9375, output === TypeError occured while reading name or country // name===MICROAIRPOLAR, Universidad Autónoma de Madrid - Meteorological State Agency of Spain
#  #############
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-192-93c4094e7654> in <module>
#       1 for s in range(999,len(df)+1):
# ----> 2     name,val=idreq(s)
#       3     print("Iteration {s}, output === {p} // name==={n} \n #############".format(s=s,p=val,n=name))
#       4     qror_list[s]=val
#
# <ipython-input-183-78f6411c60a6> in idreq(i)
#       1 def idreq(i):
#       2     try:
# ----> 3         name=df["name"][i]
#       4         country=df["country"][i]
#       5         params={"query":[name],"filter":"country.country_name:"+country}
#
# c:\users\egor\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# c:\users\egor\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 9376

# %%
len(qror_list)
# Out:
# 9376

# %%
qror_list[0:10]
# Out:
# [None,
#  'https://ror.org/04ers2y35',
#  'https://ror.org/01xtthb56',
#  'https://ror.org/02h2x0161',
#  'https://ror.org/01y9bpm73',
#  'https://ror.org/04v76ef78',
#  'https://ror.org/01se4f844',
#  None,
#  'https://ror.org/02dvf9b44',
#  'TypeError occured while reading name or country']

# %% [markdown]
# Lets insert new ROR_id column!

# %%
df.insert(0,"qROR_id",qror_list)

# %%
df
# Out:
#                                               qROR_id  id_institution  \
# 0                                                None               1
# 1                           https://ror.org/04ers2y35               4
# 2                           https://ror.org/01xtthb56               5
# 3                           https://ror.org/02h2x0161               6
# 4                           https://ror.org/01y9bpm73               8
# 5                           https://ror.org/04v76ef78               9
# 6                           https://ror.org/01se4f844              11
# 7                                                None              13
# 8                           https://ror.org/02dvf9b44              15
# 9     TypeError occured while reading name or country              17
# 10                         KeyError - query API error              18
# 11                          https://ror.org/013meh722              19
# 12                                               None              20
# 13                          https://ror.org/00hqnxt08              21
# 14                                               None              22
# 15                         KeyError - query API error              23
# 16                         KeyError - query API error              24
# 17                          https://ror.org/03wt3br81              25
# 18                          https://ror.org/00wge5k78              26
# 19                                               None              27
# 20                         KeyError - query API error              28
# 21                          https://ror.org/03zga2b32              29
# 22                         KeyError - query API error              30
# 23                                               None              31
# 24                          https://ror.org/032e6b942              32
# 25                          https://ror.org/032e6b942              33
# 26                         KeyError - query API error              34
# 27                          https://ror.org/03ycvrj88              36
# 28                          https://ror.org/04v76ef78              37
# 29                          https://ror.org/01rhff309              38
# ...                                               ...             ...
# 9346                        https://ror.org/03gz4y884           20655
# 9347  TypeError occured while reading name or country           20656
# 9348                        https://ror.org/0192yj155           20657
# 9349                        https://ror.org/017tgbk05           20658
# 9350  TypeError occured while reading name or country           20659
# 9351  TypeError occured while reading name or country           20661
# 9352  TypeError occured while reading name or country           20662
# 9353                        https://ror.org/048eb3m59           20663
# 9354                        https://ror.org/05f0yaq80           20664
# 9355                        https://ror.org/01s033b11           20665
# 9356                        https://ror.org/03be3fb73           20667
# 9357                        https://ror.org/03dkyhy49           20668
# 9358                        https://ror.org/006g31f33           20670
# 9359                        https://ror.org/01n4pqe45           20672
# 9360                        https://ror.org/02p72h367           20676
# 9361                        https://ror.org/05dnjaa32           20677
# 9362                        https://ror.org/04t3en479           20679
# 9363                        https://ror.org/01v10fv91           20681
# 9364                       KeyError - query API error           20682
# 9365                        https://ror.org/03ttqt747           20683
# 9366  TypeError occured while reading name or country           20684
# 9367  TypeError occured while reading name or country           20685
# 9368  TypeError occured while reading name or country           20686
# 9369  TypeError occured while reading name or country           20687
# 9370                       KeyError - query API error           20688
# 9371                        https://ror.org/00vgt4p82           20689
# 9372                        https://ror.org/01d0fc168           20690
# 9373  TypeError occured while reading name or country           20691
# 9374  TypeError occured while reading name or country           20692
# 9375  TypeError occured while reading name or country           20693
#
#        abbreviation                                               name  \
# 0     AWI@FRIGOROPA                         Polarstern core repository
# 1              GeoB       Department of Geosciences, Bremen University
# 2           GEOOSLO      Department of Geosciences, University of Oslo
# 3        IFM-GEOMAR  IFM-GEOMAR Leibniz-Institute of Marine Science...
# 4              IMGP  Göttinger Zentrum für Geowissenschaften, Unive...
# 5               GIK  Geologisch-Paläontologisches Institut, Christi...
# 6               IES  Institute of Geography and Earth Sciences, Uni...
# 7               RGD  Rijks Geologische Dienst, Marine Geology Depar...
# 8              IUPH  Institut für Umweltphysik, Heidelberger Akadem...
# 9               n_g                                          not_given
# 10              ARF  Antarctic Research Facility, Florida State Uni...
# 11             SPRI  Scott Polar Research Institute, University of ...
# 12             DGGE  Department of Geology and Geophysics, Universi...
# 13             MMBI               Murmansk Marine Biological Institute
# 14             CMGD  Center for Marine Geology, Dalhousie Universit...
# 15       DGG-UWisc.  Department of Geology and Geophysics, Universi...
# 16             LDEO  Lamont-Doherty Earth Observatory of Columbia U...
# 17             DGGS  Department of Geology and Geochemistry, Univer...
# 18             IBGT  Institute of Biology and Geology, University o...
# 19             WHOI  Woods Hole Oceanographic Institution, Departme...
# 20             USGS  Geological Survey, United States Department of...
# 21              GIB        Department of Geology, University of Bergen
# 22              AGC  Atlantic Geoscience Center, Bedford Institute ...
# 23          SCRIPPS  Scripps Institution of Oceanography, UC San Diego
# 24              AWI  Alfred Wegener Institute, Helmholtz Centre for...
# 25      AWI Potsdam   Alfred Wegener Institute - Research Unit Potsdam
# 26              ODP       Ocean Drilling Program, Texas A&M University
# 27              BSH  Bundesamt für Seeschiffahrt und Hydrographie, ...
# 28              IPÖ  Institut für Polarökologie, Christian-Albrecht...
# 29              BAS                British Antarctic Survey, Cambridge
# ...             ...                                                ...
# 9346           LaMP               Laboratoire de Météorologie Physique
# 9347            NaN    Institute of Geography, University of Innsbruck
# 9348            NaN  Key Laboratory of Ocean and Marginal Sea Geolo...
# 9349         ECOLAB                     Ecolab, University of Toulouse
# 9350            NaN                           LAMP / CNRS / UCA / OPGC
# 9351      Univ York                             University of York, UK
# 9352           ENEA  Laboratory for Observations and Analyses of Ea...
# 9353            NaN                    Meteorological Service Suriname
# 9354           ACES  Department of Environmental Science and Analyt...
# 9355            NaN       School of Engineering, University of Glasgow
# 9356            NMI           National Measurement Institute Australia
# 9357            NaN                         Bio-Rad Laboratories, Inc.
# 9358            NaN  Institute for Atmospheric Physics, University ...
# 9359          AGAUR  Agència de Gestió d'Ajuts Universitaris i de R...
# 9360            NaN                           University of Cincinnati
# 9361            IGP                       Instituto Geofisico del Peru
# 9362            KIT                  Karlsruhe Institute of Technology
# 9363            NaN                    Instituto Tecnológico de Sonora
# 9364            NaN                     Central Weather Bureau, Taiwan
# 9365            UMT                              University of Montana
# 9366           BMWi   Federal Ministry for Economic Affairs and Energy
# 9367            NaN  Institute of Geographic Sciences and Natural R...
# 9368           CUHK                The Chinese University of Hong Kong
# 9369            NaN                               University of Vienna
# 9370          KIOST    Korea Institute of Ocean Science and Technology
# 9371            CEN  Center for Earth System Research and Sustainab...
# 9372           ICOS               Integrated Carbon Observation System
# 9373   LTER-Austria  LTER-Austria – Gesellschaft für ökologische La...
# 9374           CAMS          Chinese Academy of Meteorological Science
# 9375  MICROAIRPOLAR  MICROAIRPOLAR, Universidad Autónoma de Madrid ...
#
#                                 city  \
# 0                  27572 Bremerhaven
# 1                       28359 Bremen
# 2                      N-0316 Oslo 3
# 3                         24148 Kiel
# 4                    37077 Göttingen
# 5                         24098 Kiel
# 6      Aberystwyth, SY23 3DB,  Wales
# 7                    2000 AD Haarlem
# 8                   69120 Heidelberg
# 9                                NaN
# 10        Tallahassee, FL 32306-3026
# 11                 Cambridge CB2 1ER
# 12                Edinburgh, EH9 3JW
# 13                   183019 Murmansk
# 14              Halifax, Nova Scotia
# 15                 Madison, WI 53706
# 16               Palisades, NY 10964
# 17                S-106 91 Stockholm
# 18                     N-9037 Tromsø
# 19              Woods Hole, MA 02543
# 20                  Reston, VA 22092
# 21                       5007 Bergen
# 22                         Dartmouth
# 23                La Jolla, CA 92093
# 24                 27568 Bremerhaven
# 25                     14401 Potsdam
# 26    College Station, TX 77845-9547
# 27                     20305 Hamburg
# 28                         2300 Kiel
# 29                Cambridge, CB3 0ET
# ...                              ...
# 9346                         Aubière
# 9347                             NaN
# 9348                       Guangzhou
# 9349                        Toulouse
# 9350                             NaN
# 9351                             NaN
# 9352                             NaN
# 9353                      Paramaribo
# 9354                             NaN
# 9355                         Glasgow
# 9356                          Sydney
# 9357            Hercules, California
# 9358                           Mainz
# 9359                             NaN
# 9360                      Cincinnati
# 9361                            Lima
# 9362                       Karlsruhe
# 9363                             NaN
# 9364                             NaN
# 9365                        Missoula
# 9366                             NaN
# 9367                             NaN
# 9368                             NaN
# 9369                             NaN
# 9370         Busan Metropolitan City
# 9371                         Hamburg
# 9372                        Helsinki
# 9373                       1070 Wien
# 9374                             NaN
# 9375                             NaN
#
#                                              contact  \
# 0                                hannes.grobe@awi.de
# 1                                                NaN
# 2                                                NaN
# 3                          wbrueckmann@ifm-geomar.de
# 4                                                NaN
# 5        name changed to Inst. für Geowissenschaften
# 6                                  glawww@aber.ac.uk
# 7                                                NaN
# 8                                       Bernd Kromer
# 9                                                NaN
# 10                 olney@gly.fsu.edu (Matthew Olney)
# 11                                               NaN
# 12                                               NaN
# 13                                    mmbi@online.ru
# 14                                               NaN
# 15                                       David Clark
# 16                                               NaN
# 17                                   Dr. Jan Backman
# 18                  Prof. Dr. Tore Vorren (Director)
# 19                            Bill Curry/James Broda
# 20                                               NaN
# 21                                               NaN
# 22                      Iris Hardy, Keith Manchester
# 23                    wsmith@ucsd.edu (Warren Smith)
# 24    Antje.Boetius@awi.de (Prof. Dr. Antje Boetius)
# 25                    Hans-Wolfgang.Hubberten@awi.de
# 26                  chris@cook.tamu.edu (Chris Mato)
# 27                                               NaN
# 28                                               NaN
# 29                           Heywood, R B (Director)
# ...                                              ...
# 9346                                             NaN
# 9347                                             NaN
# 9348                                             NaN
# 9349                                             NaN
# 9350                                             NaN
# 9351                                             NaN
# 9352                                             NaN
# 9353                                             NaN
# 9354                                             NaN
# 9355               schoolofengineering@glasgow.ac.uk
# 9356                         info@measurement.gov.au
# 9357                                             NaN
# 9358                                             NaN
# 9359                                             NaN
# 9360                                             NaN
# 9361                                             NaN
# 9362                                             NaN
# 9363                                             NaN
# 9364                                             NaN
# 9365                                             NaN
# 9366                                             NaN
# 9367                                             NaN
# 9368                                             NaN
# 9369                                             NaN
# 9370                               kiost@kiost.ac.kr
# 9371                                             NaN
# 9372                                             NaN
# 9373                                             NaN
# 9374                                             NaN
# 9375                                             NaN
#
#                                country                fax  \
# 0                              Germany  +49 471 4831 1149
# 1                              Germany   +49 421 218 3116
# 2                               Norway     +47 22 85 4215
# 3                              Germany   +49 431 600 2941
# 4                              Germany    +49 551 397 996
# 5                              Germany                NaN
# 6                       United Kingdom   +44 1970 622 780
# 7                      The Netherlands                NaN
# 8                              Germany   +49 6221 546 405
# 9                                  NaN                NaN
# 10                        Florida, USA   +01 850 644 4442
# 11                      United Kingdom                NaN
# 12                            Scotland   +44 131 668 3184
# 13                              Russia      +47 789 10288
# 14                              Kanada                NaN
# 15                      Wisconsin, USA   001 608 262 0693
# 16                       New York, USA                NaN
# 17                              Sweden     ++46 8 345 808
# 18                              Norway                NaN
# 19                                 USA     (508) 457-2187
# 20                       Virginia, USA                NaN
# 21                              Norway    +47 05 32 44 16
# 22         Nova Scotia B2Y 4A2, Canada       902 426 4465
# 23            United States of America   +01 619 534-5306
# 24                             Germany  +49 471 4831 1149
# 25                             Germany   +49 331 288 2137
# 26                          Texas, USA       409 845 4857
# 27                             Germany   +39 40 3190 5000
# 28                             Germany   +49 431 720 8720
# 29                      United Kingdom     +44 1223 62616
# ...                                ...                ...
# 9346                            France                NaN
# 9347                               NaN                NaN
# 9348                             China                NaN
# 9349                            France                NaN
# 9350                               NaN                NaN
# 9351                               NaN                NaN
# 9352                               NaN                NaN
# 9353                          Suriname                NaN
# 9354                            Sweden                NaN
# 9355                    United Kingdom                NaN
# 9356                         Australia                NaN
# 9357                     United States    +1-510-741-5817
# 9358                           Germany                NaN
# 9359                             Spain                NaN
# 9360                     United States                NaN
# 9361                              Peru                NaN
# 9362                           Germany                NaN
# 9363                            Mexico                NaN
# 9364         Taiwan, Republic of China                NaN
# 9365                     United States                NaN
# 9366                               NaN                NaN
# 9367                               NaN                NaN
# 9368                               NaN                NaN
# 9369                               NaN                NaN
# 9370  Korea, Republic of (South Korea)                NaN
# 9371                           Germany                NaN
# 9372                           Finland                NaN
# 9373                               NaN                NaN
# 9374                               NaN                NaN
# 9375                               NaN                NaN
#
#                      phone state                                       street  \
# 0        +49 471 4831 1220   NaN                            Kühlhausstrasse 9
# 1         +49 421 218 3585   NaN                         Klagenfurter Strasse
# 2           +47 22 85 6656   NaN                       P.O. Box 1047 Blindern
# 3     +49 431 600 2500 Sec   NaN                          Wischhofstrasse 1-3
# 4          +49 551 397 900   NaN                        Goldschmidt-Strasse 3
# 5                      NaN   NaN                                          NaN
# 6         +44 1970 622 781   NaN                                   Ceredigion
# 7               023-319362   NaN                                 P.O. Box 157
# 8         +49 6221 546 357   NaN                      Im Neuenheimer Feld 366
# 9                      NaN   NaN                                          NaN
# 10        +01 850 644 2407   NaN                        Department of Geology
# 11          +44 223 336540   NaN                               Lensfield Road
# 12         +44 131 6504846   NaN                              West Mains Road
# 13        +47 815 56 20 31   NaN                      Vladimirskaya Street 17
# 14                     NaN   NaN                                          NaN
# 15        001 608 262 8960   NaN                        1215 W. Dayton Street
# 16                     NaN   NaN                                       Rte 9W
# 17          ++46 8 164 720   NaN                            Kungstensgatan 45
# 18                     NaN   NaN                        P.O. Box 3985, Guleng
# 19          (508) 548-2591   NaN                                          NaN
# 20                     NaN   NaN                                          NaN
# 21            +47 05 213 0   NaN                                 Allegaten 41
# 22            902 426 6127   NaN                                P.O. Box 1006
# 23        +01 619 534-3624   NaN                                        A-020
# 24          +49 471 4831 0   NaN                              Columbusstrasse
# 25        +49 331 288 2100   NaN            Telegraphenberg, Post Box 60 0149
# 26            409 845 2673   NaN                         1000 Discovery Drive
# 27           +49 40 3190 0   NaN     Bernhard-Nocht-Straße 78, PO. Box 301220
# 28                     NaN   NaN                          Wischhofstrasse 1-3
# 29         +44 1223 251400   NaN                   High Cross, Madingley Road
# ...                    ...   ...                                          ...
# 9346                   NaN   NaN                                          NaN
# 9347                   NaN   NaN                                          NaN
# 9348                   NaN   NaN                                          NaN
# 9349                   NaN   NaN                                          NaN
# 9350                   NaN   NaN                                          NaN
# 9351                   NaN   NaN                                          NaN
# 9352                   NaN   NaN                                          NaN
# 9353                   NaN   NaN                                          NaN
# 9354                   NaN   NaN                                          NaN
# 9355    +44(0)141 330 2032   NaN                              Oakfield Avenue
# 9356      +61 1800 020 076   NaN  36 Bradfield Road, West Lindfield, NSW 2070
# 9357       +1-510-724-7000   NaN                      1000 Alfred Nobel Drive
# 9358                   NaN   NaN                                          NaN
# 9359                   NaN   NaN                                          NaN
# 9360                   NaN   NaN                                          NaN
# 9361                   NaN   NaN                            Calle Badajoz 169
# 9362                   NaN   NaN                                          NaN
# 9363                   NaN   NaN                                          NaN
# 9364                   NaN   NaN                                          NaN
# 9365                   NaN   NaN                                          NaN
# 9366                   NaN   NaN                                          NaN
# 9367                   NaN   NaN                                          NaN
# 9368                   NaN   NaN                                          NaN
# 9369                   NaN   NaN                                          NaN
# 9370     :(+82)51-664-3000   NaN   (49111) KIOST, 385, Haeyang-ro, Yeongdo-gu
# 9371                   NaN   NaN                                          NaN
# 9372                   NaN   NaN                                          NaN
# 9373                   NaN   NaN                         Schottenfeldgasse 29
# 9374                   NaN   NaN                                          NaN
# 9375                   NaN   NaN                                          NaN
#
#                                                     uri  \
# 0     http://www.awi-bremerhaven.de/GEO/CoreRepository/
# 1       http://www.geo.uni-bremen.de/page.php?langid=EN
# 2                        http://www.geo.uio.no/english/
# 3                                  http://www.geomar.de
# 4                              http://www.imgp.gwdg.de/
# 5                           http://www.ifg.uni-kiel.de/
# 6                 http://www.aber.ac.uk/~gbb/chome.html
# 7                                                   NaN
# 8                   http://www.uphys.uni-heidelberg.de/
# 9                                                   NaN
# 10                               http://www.arf.fsu.edu
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                        http://www.ldgo.columbia.edu/
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                 http://sio.ucsd.edu/
# 24                                    http://www.awi.de
# 25        http://www.awi.de/en/institute/sites/potsdam/
# 26    http://www-odp.tamu.edu or http://www.oceandri...
# 27                                    http://www.bsh.de
# 28                                                  NaN
# 29                         http://www.antarctica.ac.uk/
# ...                                                 ...
# 9346                                                NaN
# 9347                                                NaN
# 9348                        http://www.omg.scsio.ac.cn/
# 9349                          http://www.ecolab.omp.eu/
# 9350                                                NaN
# 9351                             https://www.york.ac.uk
# 9352                                                NaN
# 9353                                                NaN
# 9354                            https://www.aces.su.se/
# 9355         https://www.gla.ac.uk/schools/engineering/
# 9356                        https://measurement.gov.au/
# 9357                             http://www.bio-rad.com
# 9358                                                NaN
# 9359                                                NaN
# 9360                                                NaN
# 9361                                                NaN
# 9362                                                NaN
# 9363                                                NaN
# 9364              http://aerosol.atm.ncu.edu.tw/home/en
# 9365                               https://www.umt.edu/
# 9366   https://www.bmwi.de/Navigation/EN/Home/home.html
# 9367                                                NaN
# 9368          http://www.cuhk.edu.hk/english/index.html
# 9369                                                NaN
# 9370                     https://www.kiost.ac.kr/eng.do
# 9371             https://www.cen.uni-hamburg.de/en.html
# 9372                    https://www.icos-ri.eu/about-us
# 9373                                                NaN
# 9374                                                NaN
# 9375                                                NaN
#
#                                  uri_semantic  id_institution_type  \
# 0                                         NaN                  NaN
# 1                                         NaN                  NaN
# 2                                         NaN                  NaN
# 3                                         NaN                  NaN
# 4                                         NaN                  NaN
# 5                                         NaN                  0.0
# 6                                         NaN                  NaN
# 7                                         NaN                  NaN
# 8                                         NaN                  NaN
# 9                                         NaN                  NaN
# 10                                        NaN                  NaN
# 11                                        NaN                  NaN
# 12                                        NaN                  NaN
# 13                                        NaN                  0.0
# 14                                        NaN                  NaN
# 15                                        NaN                  NaN
# 16                                        NaN                  0.0
# 17                                        NaN                  NaN
# 18                                        NaN                  NaN
# 19                                        NaN                  NaN
# 20                                        NaN                  NaN
# 21                                        NaN                  NaN
# 22                                        NaN                  NaN
# 23                                        NaN                  NaN
# 24    http://dx.doi.org/10.13039/501100003207                  3.0
# 25                                        NaN                  0.0
# 26                                        NaN                  NaN
# 27                                        NaN                  NaN
# 28                                        NaN                  NaN
# 29                                        NaN                  NaN
# ...                                       ...                  ...
# 9346                                      NaN                  NaN
# 9347                                      NaN                  1.0
# 9348                                      NaN                  2.0
# 9349                                      NaN                  1.0
# 9350                                      NaN                  NaN
# 9351                                      NaN                  NaN
# 9352                                      NaN                  2.0
# 9353                                      NaN                  3.0
# 9354                                      NaN                  1.0
# 9355                                      NaN                  2.0
# 9356                                      NaN                  3.0
# 9357                                      NaN                  NaN
# 9358                                      NaN                  1.0
# 9359    https://doi.org/10.13039/501100003030                  NaN
# 9360                                      NaN                  1.0
# 9361                                      NaN                  2.0
# 9362                                      NaN                  2.0
# 9363                                      NaN                  2.0
# 9364                                      NaN                  3.0
# 9365                                      NaN                  1.0
# 9366  http://dx.doi.org/10.13039/501100006360                  NaN
# 9367                                      NaN                  NaN
# 9368                                      NaN                  1.0
# 9369                                      NaN                  1.0
# 9370                                      NaN                  2.0
# 9371                                      NaN                  1.0
# 9372                                      NaN                  2.0
# 9373              https://www.lter-austria.at                  NaN
# 9374                                      NaN                  2.0
# 9375                                      NaN                  2.0
#
#       id_user_created
# 0                 7.0
# 1                 7.0
# 2                 7.0
# 3                 7.0
# 4                 7.0
# 5                 7.0
# 6                 7.0
# 7                 7.0
# 8                 7.0
# 9                 7.0
# 10                7.0
# 11                7.0
# 12                7.0
# 13                7.0
# 14                7.0
# 15                7.0
# 16                7.0
# 17                7.0
# 18                7.0
# 19                7.0
# 20                7.0
# 21                7.0
# 22                7.0
# 23                7.0
# 24                7.0
# 25                7.0
# 26                7.0
# 27                7.0
# 28                7.0
# 29                7.0
# ...               ...
# 9346           2056.0
# 9347           2056.0
# 9348           7263.0
# 9349           2056.0
# 9350           2056.0
# 9351           1082.0
# 9352           2056.0
# 9353           2056.0
# 9354           2056.0
# 9355          10633.0
# 9356          10633.0
# 9357          10633.0
# 9358           2056.0
# 9359           1041.0
# 9360           2056.0
# 9361           2056.0
# 9362           2056.0
# 9363           2056.0
# 9364           2056.0
# 9365           2056.0
# 9366           1082.0
# 9367           2056.0
# 9368           2056.0
# 9369           2056.0
# 9370          10633.0
# 9371           1082.0
# 9372           1082.0
# 9373              3.0
# 9374           2056.0
# 9375           2056.0
#
# [9376 rows x 15 columns]

# %%
df.to_csv("test.csv",sep=",")

# %%
path=os.chdir("E:\PYTHON_work_learn\Python_work\Anu_Project")

# %%
os.getcwd()
# Out:
# 'E:\\PYTHON_work_learn\\Python_work\\Anu_Project'
